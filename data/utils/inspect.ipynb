# %%
import json

json_path = '/home/pgajo/checkthat24/checkthat24_DIT/data/train_gold/train_gold_sentences_new.json'

with open(json_path, 'r', encoding='utf8') as f:
    data = json.load(f)

for sample in data:
    text = sample['text']
    for ann in sample['annotations']:
        start = ann['start']
        end = ann['end']
        print(text[start:end])
        print('-------------------------')
# Out:
# польская модель, где используют очередную порцию мигрантов как дешевую силу.
# -------------------------
# английско-французские надоедливые нахлебники.
# -------------------------
# английско-французские надоедливые нахлебники
# -------------------------
# братской заботы
# -------------------------
# Беженцы не хотят возвращаться в Западную Европу: руками, ногами, зубами цепляются, чтобы не возвращаться туда.
# -------------------------
# "Беженцы не хотят возвращаться в Западную Европу: руками, ногами, зубами цепляются, чтобы не возвращаться туда.
# -------------------------
# Предполагается, что они должны получать пособия, а государства наоборот пытаются их вытолкнуть.
# -------------------------
# Россия будет делать все, чтобы быстро восстанавливать те города, которые сильно пострадали в условиях военных действий
# -------------------------
# жуткий закон
# -------------------------
# Логика государства тут понятна: нам нужно больше тел, которые смогут платить налоги,
# ...
